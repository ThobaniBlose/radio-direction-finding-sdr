# %% [markdown]
# # UCA Direction-Finding Performance versus SNR
#
# This notebook investigates how additive Gaussian noise affects the azimuth
# estimation accuracy of the UCA direction-finding system.
#
# The previously developed processing chain is retained:
#
# $$
# \text{I/Q}
# \rightarrow
# \text{FFT}
# \rightarrow
# \text{signal peak}
# \rightarrow
# \text{relative phase}
# \rightarrow
# \text{phase lookup}
# \rightarrow
# \hat{\theta}.
# $$
#
# The signal-to-noise ratio is varied while the array geometry and direction
# estimator remain unchanged.

# %%
wha
